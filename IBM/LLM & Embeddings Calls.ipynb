# %% [markdown]
# # LLMs

# %% [markdown]
# ## Langchain

# %% [markdown]
# ### Ollama phi3

# %%
# ollama -v #Verify install
# ollama list #List available models

# ollama pull phi3:mini
# # or try a small alternative:
# # ollama pull llama3.2:3b-instruct
# # ollama pull tinyllama:latest

from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="phi3:mini", base_url="http://127.0.0.1:11434")
print(llm.invoke("Hi"))

# %% [markdown]
# ### Google Gemini

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# Change to a new directory
os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
print(os.getcwd())

# Load environment variables from .env file
load_dotenv(dotenv_path="./.env",override=True, verbose=True)
# Access the variables
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
# Use the variables
print(f"GOOGLE_API_KEY: {GOOGLE_API_KEY}")


# llm = init_chat_model("google_genai:gemini-2.5-flash-lite", temperature = 0.0,max_output_tokens = 50)
# llm = init_chat_model("google_genai:gemini-2.5-flash-lite", temperature = 0.0,max_tokens = 50)
llm = init_chat_model("google_genai:gemini-2.5-flash")
llm.invoke("Hi")

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
print(os.getcwd())
load_dotenv(dotenv_path="./.env",override=True, verbose=True)

HUGGINGFACEHUB_API_TOKEN = os.getenv("HUGGINGFACEHUB_API_TOKEN")
# print(f"HUGGINGFACEHUB_API_TOKEN: {HUGGINGFACEHUB_API_TOKEN}")

llm = init_chat_model(
    "microsoft/Phi-3-mini-4k-instruct",
    model_provider="huggingface",
    # temperature=0.7,
    # max_tokens=1024,
)
llm.invoke("Hi")

# %% [markdown]
# ### ChatGPT

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
print(os.getcwd())
load_dotenv(dotenv_path="./.env",override=True, verbose=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
print(f"OPENAI_API_KEY: {OPENAI_API_KEY}")

# llm = init_chat_model(
#     "microsoft/Phi-3-mini-4k-instruct",
#     model_provider="huggingface",
#     # temperature=0.7,
#     # max_tokens=1024,
# )
# llm.invoke("Hi")

# pip install langchain langchain-openai langchain-anthropic langchain-google-vertexai

o3_mini = init_chat_model("openai:o3-mini", temperature=0)
o3_mini.invoke("what's your name")

# %% [markdown]
# ## Llama Index
# ### Ollama

# %%
from llama_index.llms.ollama import Ollama
llm = Ollama(model="phi3:mini")
print(llm.invoke("Hi"))

# %% [markdown]
# # Audio

# %% [markdown]
# ## Text to speech (TTS)

# %%
from gtts import gTTS
from IPython.display import Audio
import io

# Initialize text-to-speech with the generated story
tts = gTTS("Hi")
tts.save("./IBM/generated_story.mp3")

# %% [markdown]
# ## Speech to Text (STT)

# %%
import torch
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="openai/whisper-tiny.en",chunk_length_s=30)

# Transcribe the audio file and return the result
result = pipe(audio_file, batch_size=8)["text"]

# %% [markdown]
# # Image
# ## Text to Image

# %% [markdown]
# ### OpenAI

# %%
import os
from dotenv import load_dotenv

# Change to a new directory
os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
print(os.getcwd())

# Load environment variables from .env file
load_dotenv(dotenv_path="./.env",override=True, verbose=True)
# Access the variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# Use the variables
print(f"OPENAI_API_KEY: {OPENAI_API_KEY}")

from openai import OpenAI
from IPython import display

client = OpenAI(api_key=OPENAI_API_KEY)

response = client.images.generate(
    model="dall-e-2",
    prompt="a white siamese cat",
    size="1024x1024",
    # quality="standard",
    n=1,
)

url = response.data[0].url
display.Image(url=url, width=512)

# %% [markdown]
# ### Stability AI

# %%
import os
from dotenv import load_dotenv
from huggingface_hub import InferenceClient

# Change to a new directory
# os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
# print(os.getcwd())

# Load environment variables from .env file
load_dotenv(dotenv_path="../.env",override=True, verbose=True)

HF_TOKEN = os.getenv("HUGGINGFACE_API_KEY")
print(HF_TOKEN)

# 2) Choose a text-to-image model available on the Inference API.
#    Good defaults (pick one):
#    - "stabilityai/stable-diffusion-xl-base-1.0"  (high quality, slower)
#    - "runwayml/stable-diffusion-v1-5"            (lighter)
#    - "black-forest-labs/FLUX.1-dev"              (popular, can be slower / rate-limited)
MODEL_ID = "stabilityai/stable-diffusion-xl-base-1.0"

client = InferenceClient(model=MODEL_ID, token=HF_TOKEN)

image_bytes = client.text_to_image(prompt="A fantasy landscape, trending on artstation")
print(os.getcwd())

image_bytes.save("image.png")

# %% [markdown]
# ## Image to text

# %%
from huggingface_hub import login
login()  # You will be prompted for your HF key, which will then be saved locally

# %%
import os
from dotenv import load_dotenv
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace

# Load environment variables from .env file
load_dotenv(dotenv_path="../.env",override=True, verbose=True)
HUGGINGFACEHUB_API_TOKEN = os.getenv("HUGGINGFACEHUB_API_TOKEN")
print(f"HUGGINGFACEHUB_API_TOKEN: {HUGGINGFACEHUB_API_TOKEN}")

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-R1-0528",
    task="text-generation",
    max_new_tokens=512,
    do_sample=False,
    repetition_penalty=1.03,
    provider="auto",  # let Hugging Face choose the best provider for you
    huggingfacehub_api_token=HUGGINGFACEHUB_API_TOKEN
)

chat_model = ChatHuggingFace(llm=llm)
ai_msg = chat_model.invoke("Hi")
ai_msg.content

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")

# %% [markdown]
# # Video
# ## Text to video

# %% [markdown]
# ## Image to video

# %% [markdown]
# # Embeddings

# %% [markdown]
# ## Nomic

# %%
import os
from dotenv import load_dotenv
from langchain_nomic import NomicEmbeddings

# Change to a new directory
os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
print(os.getcwd())

# Load environment variables from .env file
load_dotenv(dotenv_path="./.env",override=True, verbose=True)
# Access the variables
NOMIC_API_KEY = os.getenv("NOMIC_API_KEY")
# Use the variables
print(f"NOMIC_API_KEY: {NOMIC_API_KEY}")


# Initialize embeddings
embeddings = NomicEmbeddings(model="nomic-embed-text-v1.5")

# %% [markdown]
# ## Hugging Face

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings()

# %% [markdown]
# # Virtual Enviornment

# %% [markdown]
# ## venv

# %%
# pip install venv 
# mkdir flask_app
# cd LC/flask_app

# python3 -m venv venv

# On linux/macOS use
# source ./venv/bin/activate :

# On Windows use
# venv\Scripts\activate :

# %% [markdown]
# ## virtualenv

# %%
# pip install virtualenv 

# virtualenv my_env # create a virtual environment named my_env
# .\my_env\Scripts\activate # activate my_env on windows
# .\my_env\Scripts\pip.exe install -r requirements.txt


# source my_env/bin/activate # activate my_env on mac and linux

# installing necessary pacakges in my_env
# python3.11 -m pip install \
# gradio==4.44.0 \
# pydantic==2.10.6 \
# ibm-watsonx-ai==1.1.2 \
# langchain==0.2.11 \
# langchain-community==0.2.10 \
# langchain-ibm==0.1.11 \
# huggingface_hub==0.23.0 

# .\gradio_env\Scripts\pip.exe install gradio pydantic langchain langchain-community huggingface_hub
