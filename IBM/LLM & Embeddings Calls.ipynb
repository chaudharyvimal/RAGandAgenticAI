# %% [markdown]
# #LLMs

# %% [markdown]
# ## Ollama

# %%
# ollama -v #Verify install
# ollama list #List available models

# ollama pull phi3:mini
# # or try a small alternative:
# # ollama pull llama3.2:3b-instruct
# # ollama pull tinyllama:latest

from langchain_ollama import OllamaLLM

llm = OllamaLLM(model="phi3:mini", base_url="http://127.0.0.1:11434")
print(llm.invoke("Hi"))
# Out:
# Hello! How can I help you today?

# %% [markdown]
# ## Google Gemini

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# Change to a new directory
os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
print(os.getcwd())

# Load environment variables from .env file
load_dotenv(dotenv_path="./.env",override=True, verbose=True)
# Access the variables
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
# Use the variables
print(f"GOOGLE_API_KEY: {GOOGLE_API_KEY}")


llm = init_chat_model("google_genai:gemini-2.5-flash-lite", temperature = 0.0,max_output_tokens = 50)
llm.invoke("Hi")
# Out:
# C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI
# GOOGLE_API_KEY: AIzaSyBT0F9-xjaoKdaJlAmvcJKm21Lf42mBvf4
# AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b596f-e006-7e11-a3ed-ffd9bc3458b1-0', usage_metadata={'input_tokens': 2, 'output_tokens': 10, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# # Embeddings

# %% [markdown]
# ## Nomic

# %%
import os
from dotenv import load_dotenv
from langchain_nomic import NomicEmbeddings

# Change to a new directory
os.chdir(r"C:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI")
print(os.getcwd())

# Load environment variables from .env file
load_dotenv(dotenv_path="./.env",override=True, verbose=True)
# Access the variables
NOMIC_API_KEY = os.getenv("NOMIC_API_KEY")
# Use the variables
print(f"NOMIC_API_KEY: {NOMIC_API_KEY}")


# Initialize embeddings
embeddings = NomicEmbeddings(model="nomic-embed-text-v1.5")

# %% [markdown]
# ## Hugging Face

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings()

# %% [markdown]
# # Virtual Enviornment

# %% [markdown]
# ## venv

# %%
# pip install venv 
# mkdir flask_app
# cd LC/flask_app

# python3 -m venv venv

# On linux/macOS use
# source ./venv/bin/activate :

# On Windows use
# venv\Scripts\activate :

# %% [markdown]
# ## virtualenv

# %%
# pip install virtualenv 
# virtualenv gradio_env # create a virtual environment named my_env
# source gradio_env/bin/activate # activate my_env on mac and linux
# .\gradio_env\Scripts\activate # activate my_env on windows

# installing necessary pacakges in my_env
# python3.11 -m pip install \
# gradio==4.44.0 \
# pydantic==2.10.6 \
# ibm-watsonx-ai==1.1.2 \
# langchain==0.2.11 \
# langchain-community==0.2.10 \
# langchain-ibm==0.1.11 \
# huggingface_hub==0.23.0 

# .\gradio_env\Scripts\pip.exe install gradio pydantic langchain langchain-community huggingface_hub
