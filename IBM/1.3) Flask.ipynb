# %%
# mkdir flask_app
# cd LC/flask_app

# python3 -m venv venv

# On linux/macOS use
# source ./venv/bin/activate :

# On Windows use
# venv\Scripts\activate :
# Out:
#   Cell In[5], line 1
#     mkdir flask_app
#           ^
# SyntaxError: invalid syntax

# %%
# from flask import Flask
# app = Flask(__name__)

# @app.route('/')
# def hello_world():
#     return 'Hello, World!'

# if __name__ == '__main__':
#     app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\ChaudharyVimal\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\interactiveshell.py:3680: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AIzaSyAifR5_keYmzHqSwM6GV0OO27hHzK-0UyM"
model = init_chat_model("google_genai:gemini-2.5-flash-lite", temperature = 0.0,max_output_tokens = 50)
llama_llm = model

model.invoke("Hi")
# Out:
# AIMessage(content='Hi there! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b3f3e-fb53-7bc1-9667-f9ccf7a47529-0', usage_metadata={'input_tokens': 2, 'output_tokens': 10, 'total_tokens': 12, 'input_token_details': {'cache_read': 0}})

# %%
# python Flask.py

# %%
# rest is in RAGandAgenticAI/flask_app/
