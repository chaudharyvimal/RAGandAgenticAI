# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ChaudharyVimal\OneDrive - Equipped AI\Equipped\A&BI\Repos\RAGandAgenticAI\IBM\5.3.1) style-finder-main

# %%
virtualenv my_env # create a virtual environment named my_env
.\my_env\Scripts\activate # activate my_env on windows
.\my_env\Scripts\pip.exe install -r requirements.txt
# Out:
#   Cell In[2], line 1
#     virtualenv my_env # create a virtual environment named my_env
#                ^
# SyntaxError: invalid syntax

# %%
wget -O swift-style-embeddings.pkl https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/95eJ0YJVtqTZhEd7RaUlew/processed-swift-style-with-embeddings.pkl
# Out:
#   Cell In[2], line 1
#     wget -O swift-style-embeddings.pkl https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/95eJ0YJVtqTZhEd7RaUlew/processed-swift-style-with-embeddings.pkl
#                                                                                                            ^
# SyntaxError: invalid decimal literal
