# %% [markdown]
# # Model

# %%
# # USe case
# 1) NER - Extract company, name, meetings
# 1.1) Meeting Summarization, Actions
# 2) ADI
# 3) Granular - mapping columns of raw file and DB
# 4) Document Summarization
# 5) Chat with your data
# 6) Genrative BI
# 7) Agents - Data Analysis, Data Prep, Data Cleaning
# 8) RAG - with DB, File System, API, other data sources
# 9) PDF miner
